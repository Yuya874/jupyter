# %%
# 必要なライブラリをインポート
from matplotlib import pyplot as p
import numpy as np

# ランダムな白黒画像を生成（256x256）
I = np.random.rand(256, 256)

# 画像を表示（グレースケールで）
p.imshow(I, cmap='gray')
p.axis('off')  # 軸を非表示にする
p.show()
